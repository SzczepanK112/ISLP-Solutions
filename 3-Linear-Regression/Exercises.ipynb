# %% [markdown]
# # *Exercises*
#
# ------
#
# ### Conceptual
#
#
#
# ### 1. Describe the null hypotheses to which the p-values given in Table 3.4 correspond. Explain what conclusions you can draw based on these p-values. Your explanation should be phrased in terms of sales, TV, radio, and newspaper, rather than in terms of the coefcients of the linear model.
#
# <div style="text-align: center;">
#     <img src="images\TABLE_3_4.png" width="800">
# </div>
#
# - p-value is defined as probability of observing test results at least as extreme as the result observed. In this case null hypothesis to which the p-values concerns can be defined as follows: there is no relationship between response and coresponding predictor.
#
# - The p-values for TV and radio are extremely small (close to 0), indicating strong evidence against the null hypothesis. This suggests that there is a significant relationship between sales and both TV and radio advertising budgets.
#
# - In contrast, the p-value for the newspaper variable is very high (0.8599), indicating insufficient evidence to reject the null hypothesis. This implies that there might not be a statistically significant relationship between newspaper advertising and sales.
#
# <br/>
#
# ### 2. Carefully explain the diferences between the KNN classifer and KNN regression methods.
#
# - KNN classifier (as name implies) is used for classification, this means it is used to output qualitative variables. Meanwhile KNN regression is a distinct type of regression that takes inspiration from KNN. It predicts continous value so it is a quantitative method.
#
# <br/>
#
# ### 3. Suppose we have a data set with five predictors:
#
# - $X_1 = \text{GPA}$
# - $X_2 = \text{IQ}$
# - $X_3 = \text{Level}$ (1 for College and 0 for High School)
# - $X_4 = $ Interaction between GPA and IQ
# - $X_5 = $ Interaction between GPA and Level
#
# The response is starting salary after graduation (in thousands of dollars). Suppose we use least squares to fit the model, and get:
#
# - $\hat{\beta}_0 = 50$
# - $\hat{\beta}_1 = 20$
# - $\hat{\beta}_2 = 0.07$
# - $\hat{\beta}_3 = 35$
# - $\hat{\beta}_4 = 0.01$
# - $\hat{\beta}_5 = -10$
#
# #### (a) Which answer is correct, and why?
#
# i. For a fixed value of IQ and GPA, high school graduates earn more, on average, than college graduates.
#
# **ii. For a fixed value of IQ and GPA, college graduates earn more, on average, than high school graduates. <---**
#
# iii. For a fixed value of IQ and GPA, high school graduates earn more, on average, than college graduates provided that the GPA is high enough.
#
# iv. For a fixed value of IQ and GPA, college graduates earn more, on average, than high school graduates provided that the GPA is high enough.
#
# #### (b) Predict the salary of a college graduate with an IQ of 110 and a GPA of 4.0.
#
# $$
# \hat{y} = \hat{\beta}_0 + \hat{\beta}_1 \cdot X_1 + \hat{\beta}_2 \cdot X_2 + \hat{\beta}_3 \cdot X_3 + \hat{\beta}_4 \cdot X_4 + \hat{\beta}_5 \cdot X_5
# $$
#
# $$
# \hat{y} = 50 + 20 \cdot 4.0 + 0.07 \cdot 110 + 35 \cdot 1 + 0.01 \cdot (4.0 \times 110) + (-10) \cdot (4.0 \cdot 1)
# $$
#
# $$ \hat{y} = 137.1 $$
#
#
# #### (c) True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.
#
# The statement is false. A small coefficient does not necessarily mean the interaction effect is insignificant. Statistical significance depends on factors like the p-value, not just the coefficient size. Even a small coefficient could be significant if the p-value is low.
#
# <br/>

# %% [markdown]
# #### 4. I collect a set of data (n = 100 observations) containing a single predictor and a quantitative response. I then fit a linear regression model to the data, as well as a separate cubic regression, i.e. $ Y = \beta_0 + \beta_1X + \beta_2X^2 + \beta_3X^3 + \epsilon $.
#
# (a) Suppose that the true relationship between $X$ and $Y$ is linear, i.e. $ Y = \beta_0 + \beta_1X + \epsilon $. Consider the training residual sum of squares (RSS) for the linear regression, and also the training RSS for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.
#
# - Training RSS for the cubic regression model will always be at least as low as that for linear regression model. Given the fact that cubic regression model is more flexible it will probably end up with lower training RSS.
#
# (b) Answer (a) using test rather than training RSS.
#
# - Since the true relationship is linear, the cubic regression model will most likely overfit the data thus resulting in far higher test RSS.
#
# (c) Suppose that the true relationship between $X$ and $Y$ is not linear, but we don’t know how far it is from linear. Consider the training RSS for the linear regression, and also the training RSS for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.
#
# - Cubic regression model should outperform linear one, again because of it's flexibility. Even though true relationship is not necessarily cubic.
#
# (d) Answer (c) using test rather than training RSS.
#
# - Similar to part (b), the cubic regression model might overfit the training data and fail to generalize well to new data. While the cubic model may have a lower training RSS, it might result in a higher test RSS compared to the linear model, which could generalize better. Therefore, we expect that the linear regression model may have a lower test RSS, despite its poorer fit to the training data.
#
# <br/>

# %% [markdown]
# #### 5. Consider the fitted values that result from performing linear regression without an intercept. In this setting, the ${i}$ th fitted value takes the form:
#
# $$
# \hat{y}_i = x_i \hat{\beta},
# $$
#
# where
#
# $$
# \hat{\beta} = \frac{\sum_{i=1}^n x_i y_i}{\sum_{i'=1}^n x_{i'}^2}.
# $$
#
# Show that we can write:
#
# $$
# \hat{y}_i = \sum_{i'=1}^n a_{i'} y_{i'},
# $$
#
# Where $a_{i'}$ is what?
# - Slope coefficent $\hat{\beta}_1$ of linear regression for mean predictor value $\bar{x}$ and mean response $\bar{y}$ equal to 0.
#
# <br/>

# %% [markdown]
# #### 6. Using (3.4), argue that in the case of simple linear regression, the least squares line always passes through the point $(\bar{x}, \bar{y})$.
#
# <div style="text-align: center;">
# <img src="images/Least_squares_equation_3_4.png">
# </div>
#
# - In order to minimize $\hat{\beta}_0$ and $\hat{\beta}_1$ we need to satisfy second equation.
# $$
# \hat{\beta}_0 = \bar{y} - \hat{\beta}_1 \bar{x}\newline
#
# \bar{y} = \hat{\beta}_1 \bar{x} + \hat{\beta}_0
# $$
#
# - Thuss the least squares line will have to pass through point $(\bar{x}, \bar{y})$
#
# <br/>
#
# #### 7. It is claimed in the text that in the case of simple linear regression of $Y$ onto $X$, the $R^2$ statistic (3.17) is equal to the square of the correlation between $X$ and $Y$ (3.18). Prove that this is the case. For simplicity, you may assume that $\bar{x} = \bar{y} = 0$.

# %% [markdown]
# <br/>
#
# $$
# R^2 = \frac{ESS}{TSS} = \frac{\sum_{i=1}^n (\hat{y_i} - \bar{y})^2}{\sum_{i=1}^n (y_i - \bar{y})^2} =
# \frac{\sum_{i=1}^n (\hat{\beta}_0 + \hat{\beta}_1 x_i - \bar{y})^2}{\sum_{i=1}^n (y_i - \bar{y})^2} =
# \frac{\sum_{i=1}^n (\bar{y} - \hat{\beta}_1 \bar{x} + \hat{\beta}_1 x_i - \bar{y})^2}{\sum_{i=1}^n (y_i - \bar{y})^2} =
# \frac{\sum_{i=1}^n (\hat{\beta}_1 (x_i - \bar{x}))^2}{\sum_{i=1}^n (y_i - \bar{y})^2} = \newline
# $$
#
# <br/>
#
# $$
# \hat{\beta}_1^2 \frac{\sum_{i=1}^n (x_i - \bar{x})^2}{\sum_{i=1}^n (y_i - \bar{y})^2} =
# \frac{(\sum{(x_i - \bar{x}) (y_i - \bar{y})}) ^ 2}{(\sum{(x_i - \bar{x})^2})^2}
# \frac{\sum_{i=1}^n (x_i - \bar{x})^2}{\sum_{i=1}^n (y_i - \bar{y})^2} =
# \frac{(\sum{(x_i - \bar{x}) (y_i - \bar{y})}) ^ 2}{\sum{(x_i - \bar{x})^2 (y_i - \bar{y})^2}} = Cor(X, Y) ^ 2
#
# $$
#
# As for $ESS$ (Explained sum of squares) i reference Wikipedia: wklej link proving that $ESS = TSS - RSS$

# %% [markdown]
# # *Applied*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF
from IPython.display import display
from ISLP import load_data
from ISLP.models import (ModelSpec as MS, summarize, poly)

sns.set_style('dark')

# %% [markdown]
# # 8. Simple Linear Regression on the Auto Data Set
#
# ### (a) Simple Linear Regression with `mpg` as the response and `horsepower` as the predictor
# Use the `sm.OLS()` function to perform a simple linear regression with `mpg` as the response and `horsepower` as the predictor. Use the `summarize()` function to print the results. Comment on the output. For example:
#   - i. Is there a relationship between the predictor and the response?
#   - ii. How strong is the relationship between the predictor and the response?
#   - iii. Is the relationship between the predictor and the response positive or negative?
#   - iv. What is the predicted `mpg` associated with a `horsepower` of 98? What are the associated 95% confidence and prediction intervals?
#
# ### (b) Plotting the Response and Predictor
# Plot the response and the predictor in a new set of axes `ax`. Use the `ax.axline()` method or the `abline()` function defined in the lab to display the least squares regression line.
#
# ### (c) Diagnostic Plots
# Produce some diagnostic plots of the least squares regression fit as described in the lab. Comment on any problems you see with the fit.

# %%
Auto = load_data("Auto")
y = Auto['mpg'] # mpg -> miles per galon
X = MS(['horsepower']).fit_transform(Auto)
model = sm.OLS(y, X)

# Slight negative relationship between horsepower and miles per galon
results = model.fit()
summarize(results)
# Out:
#                coef  std err       t  P>|t|
# intercept   39.9359    0.717  55.660    0.0
# horsepower  -0.1578    0.006 -24.489    0.0

# %%
ax = Auto.plot.scatter('horsepower', 'mpg')
xlim = ax.get_xlim()
ylim = [results.params.iloc[1] * xlim[0] + results.params.iloc[0], results.params.iloc[1] * xlim[1] + results.params.iloc[0]]
ax.grid(True)
ax.plot(xlim, ylim, 'r--', linewidth=3)

# %%
ax = plt.subplots(figsize=(8,8))[1]
ax.scatter(results.fittedvalues , results.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--')

# %%
infl = results.get_influence()
ax = plt.subplots(figsize=(8,8))[1]
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
# Out:
# Text(0, 0.5, 'Leverage')

# %% [markdown]
# # 9. Multiple Linear Regression on the Auto Data Set
#
# ### (a) Scatterplot Matrix
# Produce a scatterplot matrix which includes all of the variables in the data set.
#
# ### (b) Matrix of Correlations
# Compute the matrix of correlations between the variables using the `DataFrame.corr()` method.
#
# ### (c) Multiple Linear Regression
# Use the `sm.OLS()` function to perform a multiple linear regression with `mpg` as the response and all other variables except `name` as the predictors. Use the `summarize()` function to print the results. Comment on the output. For instance:
#   - i. Is there a relationship between the predictors and the response? Use the `anova_lm()` function from `statsmodels` to answer this question.
#   - ii. Which predictors appear to have a statistically significant relationship to the response?
#   - iii. What does the coefficient for the `year` variable suggest?
#
# ### (d) Diagnostic Plots
# Produce some diagnostic plots of the linear regression fit as described in the lab. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?
#
# ### (e) Interaction Models
# Fit some models with interactions as described in the lab. Do any interactions appear to be statistically significant?
#
# ### (f) Transformations of Variables
# Try a few different transformations of the variables, such as `log(X)`, `√X`, `X²`. Comment on your findings.

# %%
cols = Auto.columns

fig, axs = plt.subplots(8, 8, figsize=(20, 20))

for i in range(8):
  for j in range(8):
    if i == j:
      axs[i, j].hist(Auto[cols[i]], bins=20)

    else:
      axs[i, j].scatter(Auto[cols[j]], Auto[cols[i]], marker='o', s=20, alpha=0.8)


    if i < 7:
      axs[i, j].xaxis.set_visible(False)
    if j > 0:
      axs[i, j].yaxis.set_visible(False)


plt.tight_layout()

# %%
pd.plotting.scatter_matrix(Auto, figsize=(12, 12), alpha=0.8, diagonal='kde')
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='horsepower', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>,
#         <Axes: xlabel='origin', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='horsepower', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='year', ylabel='cylinders'>,
#         <Axes: xlabel='origin', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
# ...

# %%
sns.pairplot(Auto, diag_kind='kde', corner=True)
plt.show()

# %%
# b
Auto.corr()

# c
y = Auto['mpg']
terms = Auto.columns.drop('mpg')
X = MS(terms).fit_transform(Auto)
model = sm.OLS(y, X)
results = model.fit()

summarize(results)
# Out:
#                  coef  std err       t  P>|t|
# intercept    -17.2184    4.644  -3.707  0.000
# cylinders     -0.4934    0.323  -1.526  0.128
# displacement   0.0199    0.008   2.647  0.008
# horsepower    -0.0170    0.014  -1.230  0.220
# weight        -0.0065    0.001  -9.929  0.000
# acceleration   0.0806    0.099   0.815  0.415
# year           0.7508    0.051  14.729  0.000
# origin         1.4261    0.278   5.127  0.000

# %%
model = smf.ols(formula='mpg ~' + ' + '.join(terms), data=Auto)
results = model.fit()

anova_results = anova_lm(results)
anova_results
# Out:
#                  df        sum_sq       mean_sq            F         PR(>F)
# cylinders       1.0  14403.083079  14403.083079  1300.683788  2.319511e-125
# displacement    1.0   1073.344025   1073.344025    96.929329   1.530906e-20
# horsepower      1.0    403.408069    403.408069    36.430140   3.731128e-09
# weight          1.0    975.724953    975.724953    88.113748   5.544461e-19
# acceleration    1.0      0.966071      0.966071     0.087242   7.678728e-01
# year            1.0   2419.120249   2419.120249   218.460900   1.875281e-39
# origin          1.0    291.134494    291.134494    26.291171   4.665681e-07
# Residual      384.0   4252.212530     11.073470          NaN            NaN

# %% [markdown]
# - All predictors except for acceleration have statistically significant relationship to response
#
# - Because of the fact that the year variable has positive relationship with response it suggests that average value of miles per galon increases as the year pass by

# %%
ax = plt.subplots(figsize=(8,8))[1]
ax.scatter(results.fittedvalues , results.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--')

# %%
plt.figure(figsize=(8, 6))
sns.residplot(x=results.fittedvalues, y=results.resid)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted")
plt.show()

# %% [markdown]
# Residual plot suggest non-linearity in true model

# %%
infl = results.get_influence()
ax = plt.subplots(figsize=(8,8))[1]
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
# Out:
# Text(0, 0.5, 'Leverage')

# %%
np.argmax(infl.hat_matrix_diag)
# Out:
# 13

# %% [markdown]
# Observation 13 has high leverage

# %%
interaction_terms = ['cylinders:displacement', 'horsepower:displacement', 'horsepower:acceleration', 'origin:year']

model = smf.ols(formula='mpg ~ ' + ' + '.join(terms) + ' + ' + ' + '.join(interaction_terms), data=Auto)
results = model.fit()
summarize(results)
# Out:
#                             coef   std err      t  P>|t|
# Intercept                13.7393  9.160000  1.500  0.134
# cylinders                -0.0680  0.579000 -0.117  0.907
# displacement             -0.0839  0.013000 -6.239  0.000
# horsepower               -0.1477  0.047000 -3.127  0.002
# weight                   -0.0032  0.001000 -4.734  0.000
# acceleration             -0.0447  0.207000 -0.216  0.829
# year                      0.5216  0.101000  5.165  0.000
# origin                   -9.7059  4.264000 -2.276  0.023
# cylinders:displacement    0.0033  0.002000  1.378  0.169
# horsepower:displacement   0.0004  0.000084  4.891  0.000
# horsepower:acceleration  -0.0014  0.002000 -0.646  0.518
# origin:year               0.1329  0.055000  2.429  0.016

# %%
log_terms = ['np.log(' + term + ')' for term in terms]
sqrt_terms = ['np.sqrt(' + term + ')' for term in terms]
pow_terms = ['np.power(' + term + ', 2)' for term in terms]


model = smf.ols(formula='mpg ~ ' + ' + '.join(log_terms), data=Auto)
results = model.fit()
summarize(results)

# For logarithmized terms cilinders and displacement are not related to response according to statistical methods
# Out:
#                          coef  std err       t  P>|t|
# Intercept            -66.5643   17.505  -3.803  0.000
# np.log(cylinders)      1.4818    1.659   0.893  0.372
# np.log(displacement)  -1.0551    1.538  -0.686  0.493
# np.log(horsepower)    -6.9657    1.557  -4.474  0.000
# np.log(weight)       -12.5728    2.225  -5.650  0.000
# np.log(acceleration)  -4.9831    1.608  -3.099  0.002
# np.log(year)          54.9857    3.555  15.465  0.000
# np.log(origin)         1.5822    0.508   3.113  0.002

# %%
model = smf.ols(formula='mpg ~ ' + ' + '.join(sqrt_terms), data=Auto)
results = model.fit()
summarize(results)

# Cylinder count, displacement and acceleration (in square root form) does not have a notable impact on mpg
# Out:
#                           coef  std err       t  P>|t|
# Intercept             -49.7981    9.178  -5.426  0.000
# np.sqrt(cylinders)     -0.2370    1.538  -0.154  0.878
# np.sqrt(displacement)   0.2258    0.229   0.984  0.326
# np.sqrt(horsepower)    -0.7798    0.308  -2.533  0.012
# np.sqrt(weight)        -0.6217    0.079  -7.872  0.000
# np.sqrt(acceleration)  -0.8253    0.834  -0.989  0.323
# np.sqrt(year)          12.7903    0.859  14.891  0.000
# np.sqrt(origin)         3.2604    0.768   4.247  0.000

# %%
model = smf.ols(formula='mpg ~ ' + ' + '.join(pow_terms), data=Auto)
results = model.fit()
summarize(results)

# In model with squared predictors an intercept value is not statistically significant which is disturbing
# Out:
#                                    coef       std err       t  P>|t|
# Intercept                  1.208000e+00  2.356000e+00   0.513  0.608
# np.power(cylinders, 2)    -8.830000e-02  2.500000e-02  -3.502  0.001
# np.power(displacement, 2)  5.680000e-05  1.380000e-05   4.109  0.000
# np.power(horsepower, 2)   -3.621000e-05  4.980000e-05  -0.728  0.467
# np.power(weight, 2)       -9.351000e-07  8.980000e-08 -10.416  0.000
# np.power(acceleration, 2)  6.300000e-03  3.000000e-03   2.334  0.020
# np.power(year, 2)          5.000000e-03  0.000000e+00  14.160  0.000
# np.power(origin, 2)        4.129000e-01  6.900000e-02   5.971  0.000

# %%
model = smf.ols(formula='mpg ~ ' + ' + '.join(log_terms) + ' + ' + ' + '.join(terms), data=Auto)
results = model.fit()
summarize(results)

# If we create a model composed of linear terms and logarithmized terms, the standardized error increases for linear terms
# Out:
#                            coef  std err      t  P>|t|
# Intercept             3018.3055  466.814  6.466  0.000
# np.log(cylinders)       10.5205    7.685  1.369  0.172
# np.log(displacement)    -3.9398    3.349 -1.176  0.240
# np.log(horsepower)     -10.1877    3.923 -2.597  0.010
# np.log(weight)         -25.9349    7.662 -3.385  0.001
# np.log(acceleration)   -17.0284    8.072 -2.110  0.036
# np.log(year)          -833.8620  140.562 -5.932  0.000
# np.log(origin)           3.2518    3.057  1.064  0.288
# cylinders               -1.8362    1.378 -1.332  0.184
# displacement             0.0117    0.016  0.737  0.462
# horsepower               0.0291    0.033  0.870  0.385
# weight                   0.0054    0.002  2.269  0.024
# acceleration             0.8450    0.513  1.647  0.100
# year                    11.7666    1.850  6.359  0.000
# origin                  -1.1975    1.678 -0.714  0.476

# %% [markdown]
# # 10. Multiple Linear Regression on the Carseats Data Set
#
# ### (a) Fit a Multiple Regression Model
# Fit a multiple regression model to predict `Sales` using `Price`, `Urban`, and `US`.
#
# ### (b) Interpretation of Coefficients
# Provide an interpretation of each coefficient in the model. Be careful—some of the variables in the model are qualitative!
#
# ### (c) Model in Equation Form
# Write out the model in equation form, being careful to handle the qualitative variables properly.
#
# ### (d) Hypothesis Testing
# For which of the predictors can you reject the null hypothesis `H₀ : βj = 0`?
#
# ### (e) Smaller Model
# On the basis of your response to the previous question, fit a smaller model that only uses the predictors for which there is evidence of association with the outcome.
#
# ### (f) Model Fit
# How well do the models in (a) and (e) fit the data?
#
# ### (g) Confidence Intervals
# Using the model from (e), obtain 95% confidence intervals for the coefficient(s).
#
# ### (h) Outliers or High Leverage
# Is there evidence of outliers or high leverage observations in the model from (e)?

# %%
Carseats = load_data("Carseats")
Carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
sns.pairplot(Carseats, diag_kind='kde', corner=True)

# %%
model1 = smf.ols(formula='Sales ~ Price + Urban + US', data=Carseats)
results1 = model1.fit()
summarize(results1)

# Qualitative variables in model: US, Urban
# Price and Urban = Yes has a negative impact on Sales, predictor Urban has hight p-value and is not statistically significant
# Predictor US has a positive impact on Sales if it is classified as Yes
# Out:
#                  coef  std err       t  P>|t|
# Intercept     13.0435    0.651  20.036  0.000
# Urban[T.Yes]  -0.0219    0.272  -0.081  0.936
# US[T.Yes]      1.2006    0.259   4.635  0.000
# Price         -0.0545    0.005 -10.389  0.000

# %%
results1.rsquared
# Out:
# 0.23927539218405525

# %% [markdown]
# $$
# \hat{y} = \hat{\beta}_3 x_i + \hat{\beta}_2 y_i + \hat{\beta}_1 z_i + \hat{\beta}_0
# $$
#
# $\hat{\beta}_0 = $ Intercept
# $\hat{\beta}_1 = $ Urban coefficient
# $\hat{\beta}_2 = $ US coefficient
# $\hat{\beta}_3 = $ Price coefficient
#
# $z_i$ - Dummy variable equal to 1 for Urban = Yes, otherwise 0
# $y_i$ - Dummy variable equal to 1 for US = Yes, otherwise 0

# %%
model2 = smf.ols(formula='Sales ~ Price + US', data=Carseats)
results2 = model2.fit()
summarize(results2)
# Out:
#               coef  std err       t  P>|t|
# Intercept  13.0308    0.631  20.652    0.0
# US[T.Yes]   1.1996    0.258   4.641    0.0
# Price      -0.0545    0.005 -10.416    0.0

# %%
results2.rsquared
# Considering R^2 we see that both models poorly fit the real data, as most of variance in data is not explained by model.
# Both models have similar R^2 indicator however, R^2 always increases when adding a predictor vale so those two should not be compared.
# Out:
# 0.23926288842678567

# %%
results2.conf_int(alpha=0.05, cols=None)
# Out:
#                   0          1
# Intercept  11.79032  14.271265
# US[T.Yes]   0.69152   1.707766
# Price      -0.06476  -0.044195

# %%
infl = results.get_influence()
ax = plt.subplots(figsize=(8,8))[1]
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
# A few points, particularly at the beginning (indices near 0) and one near index 300, have noticeably higher leverage values.
# Out:
# Text(0, 0.5, 'Leverage')

# %%
plt.figure(figsize=(8, 6))
sns.residplot(x=results.fittedvalues, y=results.resid)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted")
plt.show()

# %% [markdown]
# ## Problem 11: Investigating the t-statistic for the null hypothesis H0: β = 0 in simple linear regression without an intercept
#
# (a) Perform a simple linear regression of y onto x, without an intercept.
#  Report the coefficient estimate $\hat {\beta}$ the standard error of this coefficient estimate, and the t-statistic and p-value associated with the null hypothesis $H_0: \beta = 0$. Comment on these results.
#
#  (b) Now perform a simple linear regression of x onto y without an intercept, and report the coefficient estimate, its standard error, and the corresponding t-statistic and p-values associated with the null hypothesis $H_0: \beta = 0$. Comment on these results.
#
# (c) What is the relationship between the results obtained in (a) and (b)?

# %%
from sklearn.preprocessing import PolynomialFeatures


rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = 2 * x + rng.normal(size=100)


xy = pd.DataFrame({'x': x, 'y': y})
MS_no1 = PolynomialFeatures(degree=1, include_bias=False)
X = MS_no1.fit_transform(xy[['x']])
model_xy = sm.OLS(y, X)  
results_xy = model_xy.fit()
summarize(results_xy)

# There is a strong relationship between x and y, probably because they were generated with the same seed,
# null hypothesis can't be rejected, though very small amount of variation in the data is explained by the model.
# Out:
#       coef  std err       t  P>|t|
# x1  1.9762    0.117  16.898    0.0

# %%
results_xy.rsquared
# Out:
# 0.7425605855144494

# %%
MS_no2 = PolynomialFeatures(degree=1, include_bias=False)
Y = MS_no2.fit_transform(xy[['y']])  
model_yx = sm.OLS(x, Y)
results_yx = model_yx.fit()
summarize(results_yx)

# Standard error is much lower, R^2 is much higher. Model fits far better
# Out:
#       coef  std err       t  P>|t|
# x1  0.3757    0.022  16.898    0.0

# %%
results_yx.rsquared
# Out:
# 0.7425605855144493

# %% [markdown]
# ## Problem 12: Simple Linear Regression without an Intercept
#
# (a) Recall that the coefficient estimate $\beta$ for the linear regression of Y onto X without an intercept is given by (3.38). Under what circumstance is the coefficient estimate for the regression of X onto Y the same as the coefficient estimate for the regression of Y onto X?
#
# (b) Generate an example in Python with n = 100 observations in which the coefficient estimate for the regression of X onto Y is different from the coefficient estimate for the regression of Y onto X.
#
# (c) Generate an example in Python with n = 100 observations in which the coefficient estimate for the regression of X onto Y is the same as the coefficient estimate for the regression of Y onto X.

# %%
# A -> When Beta == 1


# C
rng1 = np.random.default_rng(1)

x = rng1.normal(size=100)
y = rng1.normal(size=100)

MS_no1 = PolynomialFeatures(degree=1, include_bias=False)
MS_no2 = PolynomialFeatures(degree=1, include_bias=False)
Y = MS_no2.fit_transform(xy[['y']])  
model_yx = sm.OLS(x, Y)
results_yx = model_yx.fit()
summarize(results_yx)

xy = pd.DataFrame({'x': x, 'y': y})
MS_no1 = MS(['x'], intercept=False)
X = MS_no1.fit_transform(xy)

model_xy = sm.OLS(y, X)
results_xy = model_xy.fit()
summarize(results_xy)
# Out:
#      coef  std err      t  P>|t|
# x -0.0238    0.117 -0.203  0.839

# %%
xy = pd.DataFrame({'x': x, 'y': y})
MS_no2 = MS(['y'], intercept=False)
Y = MS_no1.fit_transform(xy)

model_yx = sm.OLS(x, Y)
results_yx = model_xy.fit()
summarize(results_yx)
# Out:
#      coef  std err      t  P>|t|
# x -0.0238    0.117 -0.203  0.839

# %%
# B

rng2 = np.random.default_rng(21)

x = rng1.normal(size=100)
y = 2 * rng2.normal(size=100)

MS_no1 = PolynomialFeatures(degree=1, include_bias=False)
MS_no2 = PolynomialFeatures(degree=1, include_bias=False)
Y = MS_no2.fit_transform(xy[['y']])  
model_yx = sm.OLS(x, Y)
results_yx = model_yx.fit()
summarize(results_yx)

xy = pd.DataFrame({'x': x, 'y': y})
MS_no1 = MS(['x'], intercept=False)
X = MS_no1.fit_transform(xy)

model_xy = sm.OLS(y, X)
results_xy = model_xy.fit()
summarize(results_xy)
# Out:
#      coef  std err      t  P>|t|
# x  0.1636    0.191  0.858  0.393

# %%
xy = pd.DataFrame({'x': x, 'y': y})
MS_no2 = MS(['y'], intercept=False)
Y = MS_no1.fit_transform(xy)

model_yx = sm.OLS(x, Y)
results_yx = model_xy.fit()
summarize(results_yx)
# Out:
#      coef  std err      t  P>|t|
# x  0.1636    0.191  0.858  0.393

# %% [markdown]
# ## Problem 13: Simulated Data and Simple Linear Regression Models
#
#  (a) Using the normal() method of your random number generator, create a vector $x$, containing 100 observations drawn from a N(0, 1) distribution. This represents a feature, $X$.
#
#  (b) Using the normal() method, create a vector, eps, containing 100 observations drawn from a N(0, 0.25) distribution—a normal distribution with mean zero and variance 0.25.
#
#  (c) Using x and eps, generate a vector y according to the model:
# $ Y = -1 + 0.5X + \epsilon $ .
#
#  What is the length of the vector y? What are the values of $\beta_0$ and $\beta_1$ in this linear model?
#
#  (d) Create a scatterplot displaying the relationship between x and y. Comment on what you observe.
#
#  (e) Fit a least squares linear model to predict y using x. Comment on the model obtained. How do $\hat{\beta}_0$ and $\hat{\beta}_1$ compare to $\beta_0$ and $\beta_1$?
#
#  (f) Display the least squares line on the scatterplot obtained in (d). Draw the population regression line on the plot, in a different color. Use the legend() method of the axes to create an appropriate legend.
#
#  (g) Now fit a polynomial regression model that predicts $y$ using $x$ and $x^2$. Is there evidence that the quadratic term improves the model fit? Explain your answer.
#
#  (h) Repeat (a)–(f) after modifying the data generation process in such a way that there is less noise in the data. The model (3.39) should remain the same. You can do this by decreasing the variance of the normal distribution used to generate the error term ε in (b). Describe your results.
#
#  (i) Repeat (a)–(f) after modifying the data generation process in such a way that there is more noise in the data. The model (3.39) should remain the same. You can do this by increasing the variance of the normal distribution used to generate the error term ε in (b). Describe your results.
#
#  (j) What are the confidence intervals for $\beta_0$ and $\beta_1$ based on the original data set, the noisier data set, and the less noisy data set? Comment on your results.

# %%
x = rng.normal(size=100, loc=0, scale=1)
eps = rng.normal(size=100, loc=0, scale=0.5)

y = -1 + 0.5 * x + eps
# Length of Y = 100, beta_0 = -1, beta_1 = 0.5


sns.scatterplot(x=x, y=y)
plt.grid()
# Because of noise vector data is not so easy to interpret but a linear relationship is still visible

# %%
X = sm.add_constant(x)

model_xy = sm.OLS(y, X)
results_xy = model_xy.fit()
summarize(results_xy)


# Both beta_0 and beta_1 are close to real model coeficients, predicted beta_0 only at the third
# decimal place from the actual model coefficient, beta_1 however is a bit overestimated
# Out:
#          coef  std err       t  P>|t|
# const -1.0023    0.044 -22.535    0.0
# x1     0.5475    0.048  11.413    0.0

# %%
ax = sns.scatterplot(x=x, y=y)
x_range = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100)
y_pred = results_xy.params[0] + results_xy.params[1] * x_range
reg = ax.plot(x_range, y_pred, 'r--', linewidth=2, label="Regression line")
plt.grid()
plt.legend()
plt.show()

# %%
yx = pd.DataFrame({'y': y, 'x': x})

X = MS([poly('x', degree=2)]).fit_transform(yx)


model_xy_quadratic = sm.OLS(y, X)
results_xy_quadratic = model_xy_quadratic.fit()
summarize(results_xy_quadratic)
# Out:
#                         coef  std err       t  P>|t|
# intercept            -1.0905    0.044 -24.775  0.000
# poly(x, degree=2)[0]  4.9991    0.440  11.358  0.000
# poly(x, degree=2)[1]  0.1076    0.440   0.244  0.807

# %%
results_xy.rsquared, results_xy_quadratic.rsquared
# Out:
# (0.5706397551809558, 0.5709040515517512)

# %%
ax = sns.scatterplot(x=x, y=y)
x_range = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100)
beta0, beta1, beta2 = results_xy_quadratic.params.iloc[0], results_xy_quadratic.params.iloc[1], results_xy_quadratic.params.iloc[2]
y_pred = beta0 + beta1 * x_range + beta2 * (x_range ** 2)
reg = ax.plot(x_range, y_pred, 'r--', linewidth=2, label="Regression line")
plt.grid()
plt.title("Default quadratic regression from ISLP")
plt.legend()
plt.show()

# I honestly have no idea why this happens, it looks like beta1 is multiplied by 10 somwhere but I can't figure it out

# %%
ax = sns.scatterplot(x=x, y=y)
x_range = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100)
beta0, beta1, beta2 = results_xy_quadratic.params.iloc[0], results_xy_quadratic.params.iloc[1] / 10, results_xy_quadratic.params.iloc[2]
y_pred = beta0 + beta1 * x_range + beta2 * (x_range ** 2)
reg = ax.plot(x_range, y_pred, 'r--', linewidth=2, label="Regression line")
plt.grid()
plt.title("Quadratic regression from ISLP with linear coefficient divided by 10")
plt.legend()
plt.show()

# %%
sns.residplot(x=results_xy.fittedvalues, y=results_xy.resid)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted")
plt.show()

# %%
sns.residplot(x=results_xy_quadratic.fittedvalues, y=results_xy_quadratic.resid)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted")
plt.show()

# Also residuals for both models are very similiar which can't be true because we clearly see that default output
# doesn't fit the data at all

# %%
anova_lm(results_xy, results_xy_quadratic)

# ANOVA confirms that quadratic polynomial doesn't improve the model
# Out:
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0      98.0  18.803358      0.0       NaN       NaN       NaN
# 1      97.0  18.791784      1.0  0.011575  0.059746  0.807414

# %%
# Here I created one more model, using scikitlearn

polynomial = PolynomialFeatures(degree=2)
x_poly = polynomial.fit_transform(x.reshape(-1, 1))

model_xy_quadratic = sm.OLS(y, x_poly)
results_xy_quadratic = model_xy_quadratic.fit()
summarize(results_xy_quadratic)

# Coefficients are more realistic, however here p-value for quadratic term is high enough to view it as not corelated with data
# Out:
#          coef  std err       t  P>|t|
# const -1.0091    0.053 -19.211  0.000
# x1     0.5463    0.048  11.281  0.000
# x2     0.0076    0.031   0.244  0.807

# %%
ax = sns.scatterplot(x=x, y=y)
x_range = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100)
beta0, beta1, beta2 = results_xy_quadratic.params[0], results_xy_quadratic.params[1], results_xy_quadratic.params[2]
y_pred = beta0 + beta1 * x_range + 0.1 * (x_range ** 2)
reg = ax.plot(x_range, y_pred, 'r--', linewidth=2, label="Regression line")
plt.grid()
plt.legend()
plt.show()

# %%
results_xy.rsquared, results_xy_quadratic.rsquared
# Out:
# (0.5706397551809558, 0.5709040515517511)

# %%
sns.residplot(x=results_xy_quadratic.fittedvalues, y=results_xy_quadratic.resid)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted (scikit-learn model)")
plt.show()

# %%
anova_lm(results_xy, results_xy_quadratic)
# Quadratic model bears no statistialy significant improvement
# Out:
#    df_resid        ssr  df_diff   ss_diff         F    Pr(>F)
# 0      98.0  18.803358      0.0       NaN       NaN       NaN
# 1      97.0  18.791784      1.0  0.011575  0.059746  0.807414

# %%
eps = rng.normal(size=100, loc=0, scale=0.25)
y = -1 + 0.5 * x + eps

X = sm.add_constant(x)
model_xy = sm.OLS(y, X)
results_xy_less_err = model_xy.fit()
summarize(results_xy_less_err)
# Out:
#          coef  std err       t  P>|t|
# const -0.9728    0.022 -43.585    0.0
# x1     0.4365    0.024  18.130    0.0

# %%
polynomial = PolynomialFeatures(degree=2)
x_poly = polynomial.fit_transform(x.reshape(-1, 1))

model_xy_quadratic = sm.OLS(y, x_poly)
results_xy_quadratic_less_err = model_xy_quadratic.fit()
summarize(results_xy_quadratic_less_err)

# Again quadratic coefficient doesn't have siginificant correlation to the output
# Out:
#          coef  std err       t  P>|t|
# const -0.9647    0.026 -36.651  0.000
# x1     0.4378    0.024  18.042  0.000
# x2    -0.0092    0.016  -0.590  0.556

# %%
results_xy_less_err.rsquared, results_xy_quadratic_less_err.rsquared
# Out:
# (0.7703335319899957, 0.7711550862144336)

# %%
anova_lm(results_xy_less_err, results_xy_quadratic_less_err)

# P-value has decreased in comparison to default model, but it's nowhere near for quadratic regression to be a better fit
# Out:
#    df_resid       ssr  df_diff   ss_diff        F    Pr(>F)
# 0      98.0  4.735161      0.0       NaN      NaN       NaN
# 1      97.0  4.718222      1.0  0.016938  0.34823  0.556489

# %%
eps = rng.normal(size=100, loc=0, scale=1)

y = -1 + 0.5 * x + eps

X = sm.add_constant(x)
model_xy = sm.OLS(y, X)
results_xy_more_err = model_xy.fit()
summarize(results_xy_more_err)
# Out:
#          coef  std err      t  P>|t|
# const -1.0644    0.113 -9.399    0.0
# x1     0.6250    0.122  5.117    0.0

# %%
polynomial = PolynomialFeatures(degree=2)
x_poly = polynomial.fit_transform(x.reshape(-1, 1))

model_xy_quadratic = sm.OLS(y, x_poly)
results_xy_quadratic_more_err = model_xy_quadratic.fit()
summarize(results_xy_quadratic_more_err)
# Out:
#          coef  std err      t  P>|t|
# const -1.1693    0.132 -8.842  0.000
# x1     0.6072    0.122  4.980  0.000
# x2     0.1186    0.079  1.509  0.134

# %%
results_xy_more_err.rsquared, results_xy_quadratic_more_err.rsquared
# Out:
# (0.21082726711898614, 0.22893294154991528)

# %%
anova_lm(results_xy_more_err, results_xy_quadratic_more_err)

# For increased variance quadratic model's p-value in anova has decreased from 0.8 to 0.13, still linear model is a better fit
# Out:
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0      98.0  121.901146      0.0       NaN       NaN       NaN
# 1      97.0  119.104417      1.0  2.796729  2.277688  0.134498

# %%
# Confidence intervals for every coefficient

results_xy.conf_int(), results_xy_quadratic.conf_int()
# Out:
# (array([[-1.09061269, -0.91407978],
#         [ 0.45228109,  0.64267738]]),
#  array([[-1.11334452, -0.90483929],
#         [ 0.45021692,  0.64245586],
#         [-0.05434371,  0.06960922]]))

# %%
results_xy_less_err.conf_int(), results_xy_quadratic_less_err.conf_int()
# Out:
# (array([[-1.01712444, -0.92853635],
#         [ 0.38868081,  0.48422585]]),
#  array([[-1.01690871, -0.91243136],
#         [ 0.38967252,  0.48599919],
#         [-0.04028851,  0.02182155]]))

# %%
results_xy_more_err.conf_int(), results_xy_quadratic_more_err.conf_int()

# For quadratic regression
# Quadratic element coefficent confidence interval is largest with moderate error variation, for smaller and bigger error they are similar
# Intercept and linear coefficent behave the same as with linear regression

# For linear regression model we see nothing out of the ordinary, with increase of error confidence interval increases for both coefficients
# Out:
# (array([[-1.28919076, -0.83970923],
#         [ 0.38258277,  0.86736275]]),
#  array([[-1.43176935, -0.90684482],
#         [ 0.36522141,  0.84919457],
#         [-0.03738328,  0.27467573]]))

# %% [markdown]
# ### 14. This problem focuses on the collinearity problem.
# (a) Perform the following commands in Python:
# `rng = np.random.default_rng(10)`
# `x1 = rng.uniform(0, 1, size=100)`
# `x2 = 0.5 * x1 + rng.normal(size=100) / 10`
# `y = 2 + 2 * x1 + 0.3 * x2 + rng.normal(size=100)`
# The last line corresponds to creating a linear model in which y is
# a function of $x_1$ and $x_2$. Write out the form of the linear model.
# What are the regression coefcients?
#
# (b) What is the correlation between $x_1$ and $x_2$? Create a scatterplot
# displaying the relationship between the variables.
#
# (c) Using this data, fit a least squares regression to predict y using
# x1 and x2. Describe the results obtained. What are $\hat{\beta}_0$, $\hat{\beta}_1$, and
# $\hat{\beta}_2$? How do these relate to the true ${\beta}_0$, ${\beta}_1$, and ${\beta}_2$? Can you
# reject the null hypothesis $H_0 : {\beta}_1 = 0$? How about the null
# hypothesis $H_0 : {\beta}_2 = 0$?
#
# (d) Now fit a least squares regression to predict y using only $x_1$.
# Comment on your results. Can you reject the null hypothesis
# $H_0 : {\beta}_1 = 0$?
#
# (e) Now fit a least squares regression to predict y using only $x_2$.
# Comment on your results. Can you reject the null hypothesis
# $H_0 : {\beta}_1 = 0$?
#
# (f) Do the results obtained in (c)–(e) contradict each other? Explain
# your answer.
#
# (g) Suppose we obtain one additional observation, which was unfortunately mismeasured. We use the function `np.concatenate()` to add this additional observation to each of $x_1$, $x_2$ and $y$.
# `x1 = np.concatenate([x1, [0.1]])`
# `x2 = np.concatenate([x2, [0.8]])`
# `y = np.concatenate([y, [6]])`
# Re-fit the linear models from (c) to (e) using this new data. What
# efect does this new observation have on the each of the models?
# In each model, is this observation an outlier? A high-leverage
# point? Both? Explain your answers.

# %%
rng = np.random.default_rng(10)
x1 = rng.uniform(0, 1, size=100)
x2 = 0.5 * x1 + rng.normal(size=100) / 10
y = 2 + 2 * x1 + 0.3 * x2 + rng.normal(size=100)

# %% [markdown]
# $Y = 2 x_1 + 0.3 x_2 + 2 + \epsilon$

# %%
collinear_df = pd.DataFrame({'y': y, 'x1': x1, 'x2': x2})
model_collinear = smf.ols(formula='y ~ x1 + x2', data=collinear_df)

results_collinear = model_collinear.fit()
results_collinear.summary()

# Beta_1 is underestimated while beta_2 is overestimated. Null hypothesis H0: B2 = 0 cannot be rejected.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     19.89
# Date:                Wed, 11 Dec 2024   Prob (F-statistic):           5.76e-08
# Time:                        09:15:14   Log-Likelihood:                -130.62
# No. Observations:                 100   AIC:                             267.2
# Df Residuals:                      97   BIC:                             275.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9579      0.190     10.319      0.000       1.581       2.334
# ...

# %%
collinear_df['x1'].corr(collinear_df['x2'])
# Out:
# 0.7723244976913538

# %%
sns.scatterplot(x='x1', y='x2', data=collinear_df)
plt.grid()

# %%
model_collinear_x1 = smf.ols(formula='y ~ x1', data=collinear_df)

results_collinear_x1 = model_collinear_x1.fit()
results_collinear_x1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     38.39
# Date:                Wed, 11 Dec 2024   Prob (F-statistic):           1.37e-08
# Time:                        09:15:14   Log-Likelihood:                -131.28
# No. Observations:                 100   AIC:                             266.6
# Df Residuals:                      98   BIC:                             271.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9371      0.189     10.242      0.000       1.562       2.312
# ...

# %%
model_collinear_x2 = smf.ols(formula='y ~ x2', data=collinear_df)

results_collinear_x2 = model_collinear_x2.fit()
results_collinear_x2.summary()

# In both cases of linear regression with only one predictor p-value is equal to 0, thuss null hypothesis shuld be rejected. 
# Because of that it is clear that results from simple linear regression contradict those of multiple linear regression
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     27.99
# Date:                Wed, 11 Dec 2024   Prob (F-statistic):           7.43e-07
# Time:                        09:15:14   Log-Likelihood:                -135.24
# No. Observations:                 100   AIC:                             274.5
# Df Residuals:                      98   BIC:                             279.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.3239      0.154     15.124      0.000       2.019       2.629
# ...

# %%
x1 = np.concatenate([x1, [0.1]])
x2 = np.concatenate([x2, [0.8]])
y = np.concatenate([y, [6]])

collinear_df = pd.DataFrame({'y': y, 'x1': x1, 'x2': x2})
model_collinear = smf.ols(formula='y ~ x1 + x2', data=collinear_df)

results_collinear = model_collinear.fit()
summarize(results_collinear)

# Mismeasured observation changed regression model. Now it's x1 which appears to be uncorelated
# Out:
#              coef  std err       t  P>|t|
# Intercept  2.0618    0.192  10.720  0.000
# x1         0.8575    0.466   1.838  0.069
# x2         2.2663    0.705   3.216  0.002

# %%
model_collinear_x1 = smf.ols(formula='y ~ x1', data=collinear_df)

results_collinear_x1 = model_collinear_x1.fit()
summarize(results_collinear_x1)
# Out:
#              coef  std err       t  P>|t|
# Intercept  2.0739    0.201  10.310    0.0
# x1         1.8760    0.358   5.236    0.0

# %%
model_collinear_x2 = smf.ols(formula='y ~ x2', data=collinear_df)

results_collinear_x2 = model_collinear_x2.fit()
summarize(results_collinear_x2)
# Standardized error has decreased for regression with only x2 and increased for regression with x1
# Out:
#              coef  std err       t  P>|t|
# Intercept  2.2840    0.151  15.088    0.0
# x2         3.1458    0.524   6.008    0.0

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
fig.supxlabel("Index")

sns.residplot(ax=axes[0], x=results_collinear.fittedvalues.index, y=results_collinear.resid)
axes[0].set_ylabel("Residuals")
axes[0].set_title("Model with both predictors")

sns.residplot(ax=axes[1], x=results_collinear_x1.fittedvalues.index, y=results_collinear_x1.resid)
axes[1].set_title("Model with x1 as predictor")

sns.residplot(ax=axes[2], x=results_collinear_x2.fittedvalues.index, y=results_collinear_x2.resid)
axes[2].set_title("Model with x2 as predictor")

plt.tight_layout()
plt.show()

# New observation is an outlier only for model with only x1 as predictor

# %%
inflx1x2 = results_collinear.get_influence()
inflx1 = results_collinear_x1.get_influence()
inflx2 = results_collinear_x2.get_influence()

fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
fig.supxlabel("Index")

sns.residplot(ax=axes[0], x=results_collinear.fittedvalues.index, y=inflx1x2.hat_matrix_diag)
axes[0].set_ylabel("Leverage")
axes[0].set_title("Model with both predictors")

sns.residplot(ax=axes[1], x=results_collinear_x1.fittedvalues.index, y=inflx1.hat_matrix_diag)
axes[1].set_title("Model with x1 as predictor")

sns.residplot(ax=axes[2], x=results_collinear_x2.fittedvalues.index, y=inflx2.hat_matrix_diag)
axes[2].set_title("Model with x2 as predictor")

plt.tight_layout()
plt.show()

# New observation has incredibly high leverage in model with both predictors taken into account
# Model with x2 as predictor also assigns high leverage for mismeasured observation

# %% [markdown]
# ### 15. This problem involves the Boston data set, which we saw in the lab for this chapter. We will now try to predict per capita crime rate using the other variables in this data set. In other words, per capita crime rate is the response, and the other variables are the predictors.
#
# (a) For each predictor, fit a simple linear regression model to predict
# the response. Describe your results. In which of the models is
# there a statistically signifcant association between the predictor
# and the response? Create some plots to back up your assertions.
#
# (b) Fit a multiple regression model to predict the response using
# all of the predictors. Describe your results. For which predictors
# can we reject the null hypothesis $H_0 : \beta_j = 0$?
#
# (c) How do your results from (a) compare to your results from (b)?
# Create a plot displaying the univariate regression coefcients
# from (a) on the x-axis, and the multiple regression coefcients
# from (b) on the y-axis. That is, each predictor is displayed as a
# single point in the plot. Its coefcient in a simple linear regression model is shown on the x-axis, and its coefcient estimate
# in the multiple linear regression model is shown on the y-axis.
#
# (d) Is there evidence of non-linear association between any of the
# predictors and the response? To answer this question, for each
# predictor X, fit a model of the form:
#
# $Y = \beta_0 + \beta_1 X + \beta_2 X^2 + \beta_3 X^3 + \epsilon$

# %%
Boston = load_data("Boston")
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
predictors = Boston.columns.drop('crim')
results = []

for predictor in predictors:
  model = smf.ols(f'crim ~ {predictor}', data=Boston)
  fit = model.fit()
  results.append(fit)

  print(f"Model: crim ~ {predictor}")
  display(summarize(fit))
# Out:
# Model: crim ~ zn
#              coef  std err       t  P>|t|
# Intercept  4.4537    0.417  10.675    0.0
# zn        -0.0739    0.016  -4.594    0.0
# Model: crim ~ indus
#              coef  std err      t  P>|t|
# Intercept -2.0637    0.667 -3.093  0.002
# indus      0.5098    0.051  9.991  0.000
# Model: crim ~ chas
#              coef  std err      t  P>|t|
# Intercept  3.7444    0.396  9.453  0.000
# chas      -1.8928    1.506 -1.257  0.209
# Model: crim ~ nox
#               coef  std err       t  P>|t|
# Intercept -13.7199    1.699  -8.073    0.0
# nox        31.2485    2.999  10.419    0.0
# Model: crim ~ rm
#               coef  std err      t  P>|t|
# Intercept  20.4818    3.364  6.088    0.0
# rm         -2.6841    0.532 -5.045    0.0
# Model: crim ~ age
#              coef  std err      t  P>|t|
# Intercept -3.7779    0.944 -4.002    0.0
# age        0.1078    0.013  8.463    0.0
# Model: crim ~ dis
#              coef  std err       t  P>|t|
# ...

# %%
ax = sns.scatterplot(x='dis', y='crim', data=Boston)

beta0, beta1 = results[6].params.iloc[0], results[6].params.iloc[1]
x_range = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100)
y_pred = beta0 + beta1 * x_range
reg = ax.plot(x_range, y_pred, 'r--', linewidth=2, label="Regression line")
plt.grid()
plt.show()

# Here p-value for 'dis' but regression line is completely out of place for high values of 'dis'

# %%
# If we look at the predictors in simple linear regression model, all of them except for chas have low p-value,
# probably because of correlation between predictors. After creating multilinear model we see big increase in p-value for many predictors
# we can reject null hypothesis for the following predictors: zn, dis, rad, medv
model = smf.ols(formula='crim ~ ' + ' + '.join(predictors), data=Boston)
result = model.fit()
summarize(result)
# Out:
#               coef  std err      t  P>|t|
# Intercept  13.7784    7.082  1.946  0.052
# zn          0.0457    0.019  2.433  0.015
# indus      -0.0584    0.084 -0.698  0.486
# chas       -0.8254    1.183 -0.697  0.486
# nox        -9.9576    5.290 -1.882  0.060
# rm          0.6289    0.607  1.036  0.301
# age        -0.0008    0.018 -0.047  0.962
# dis        -1.0122    0.282 -3.584  0.000
# rad         0.6125    0.088  6.997  0.000
# tax        -0.0038    0.005 -0.730  0.466
# ptratio    -0.3041    0.186 -1.632  0.103
# lstat       0.1388    0.076  1.833  0.067
# medv       -0.2201    0.060 -3.678  0.000

# %%
correlation_matrix = Boston.corr()
correlation_matrix
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
params_multiple = result.params[1:]
params_univariate = [result.params.iloc[1] for result in results]


s = [abs(pu - pm) for pu, pm in zip(params_univariate, params_multiple)]
ax = sns.scatterplot(x=params_multiple, y=params_univariate, hue=params_multiple.index, size=s, legend='brief')

handles, labels = ax.get_legend_handles_labels()
legend_labels = [label for label in labels if label in params_multiple.index]
ax.legend(handles[:len(legend_labels)], legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_xlabel("Multiple regression coefficients")
ax.set_ylabel("Univariate regression coefficients")
ax.grid()

# Biggest diference can be observed for the predictor 'nox' where multiple regression coefficient is equal to -10 while for univariate it
# exceeds 30.
# 
# Few coefficents araound zero have similar values, there are 3 coefficnets which are different eg.
# -> ptratio for univariate regression =~ 1.15, while for multiple regression =~ -0.3

# %%
X = Boston.drop(columns='crim')
X_names = X.columns

poly_features = {
    f"{name}^{power}": np.power(X[name], power)
    for name in X_names
    for power in [1, 2, 3]
}

poly_df = pd.DataFrame(poly_features)

y = Boston['crim'].values

poly_df = sm.add_constant(poly_df)

non_linear_model = sm.OLS(y, poly_df)
results = non_linear_model.fit()

summarize(results)
# Out:
#                    coef       std err      t  P>|t|
# const     -3.902640e+01  1.448320e+02 -0.269  0.788
# zn^1      -4.860000e-02  9.300000e-02 -0.521  0.603
# zn^2       1.500000e-03  3.000000e-03  0.511  0.609
# zn^3      -9.627000e-06  2.390000e-05 -0.403  0.687
# indus^1    1.391000e-01  6.990000e-01  0.199  0.842
# indus^2    4.000000e-03  6.300000e-02  0.064  0.949
# indus^3   -4.000000e-04  2.000000e-03 -0.230  0.819
# chas^1     1.146000e-01  3.600000e-01  0.319  0.750
# chas^2     1.154000e-01  3.600000e-01  0.321  0.749
# chas^3     1.153000e-01  3.600000e-01  0.320  0.749
# nox^1      4.834747e+02  2.302180e+02  2.100  0.036
# nox^2     -8.100849e+02  3.744850e+02 -2.163  0.031
# nox^3      4.204621e+02  1.978110e+02  2.126  0.034
# rm^1      -3.790500e+00  2.578700e+01 -0.147  0.883
# rm^2       2.580000e-01  4.142000e+00  0.062  0.950
# rm^3       7.400000e-03  2.180000e-01  0.034  0.973
# age^1      7.820000e-02  1.450000e-01  0.540  0.589
# ...

# %%
dis_poly = poly_df[['dis^1', 'dis^2', 'dis^3']]
dis_poly = sm.add_constant(dis_poly)


dis_model = sm.OLS(y, dis_poly)
results = dis_model.fit()

summarize(results)
# Out:
#           coef  std err       t  P>|t|
# const  30.0476    2.446  12.285    0.0
# dis^1 -15.5544    1.736  -8.960    0.0
# dis^2   2.4521    0.346   7.078    0.0
# dis^3  -0.1186    0.020  -5.814    0.0

# %%
beta0, beta1, beta2, beta3 = results.params

ax = sns.scatterplot(x='dis', y='crim', data=Boston)
x_range = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100)
y_pred = beta0 + beta1 * x_range + beta2 * x_range ** 2 + beta3 * x_range ** 3
reg = ax.plot(x_range, y_pred, 'r--', linewidth=2, label="Regression line")
plt.grid()

# Regression line fits well for dis between 0 and 8
